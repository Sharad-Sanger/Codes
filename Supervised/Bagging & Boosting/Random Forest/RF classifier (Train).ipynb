# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\DELL\\Documents\\Python\\CSV\\Train.csv')

# %%
df.head()
# Out:
#   INCIDENT_ID       DATE  X_1  X_2  X_3  X_4  X_5  X_6  X_7  X_8  X_9  X_10  \
# 0   CR_102659  04-JUL-04    0   36   34    2    1    5    6    1    6     1
# 1   CR_189752  18-JUL-17    1   37   37    0    0   11   17    1    6     1
# 2   CR_184637  15-MAR-17    0    3    2    3    5    1    0    2    3     1
# 3   CR_139071  13-FEB-09    0   33   32    2    1    7    1    1    6     1
# 4   CR_109335  13-APR-05    0   33   32    2    1    8    3    0    5     1
#
#    X_11  X_12  X_13  X_14  X_15  MALICIOUS_OFFENSE
# 0   174   1.0    92    29    36                  0
# 1   236   1.0   103   142    34                  1
# 2   174   1.0   110    93    34                  1
# 3   249   1.0    72    29    34                  1
# 4   174   0.0   112    29    43                  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   INCIDENT_ID        23856 non-null  object
#  1   DATE               23856 non-null  object
#  2   X_1                23856 non-null  int64
#  3   X_2                23856 non-null  int64
#  4   X_3                23856 non-null  int64
#  5   X_4                23856 non-null  int64
#  6   X_5                23856 non-null  int64
#  7   X_6                23856 non-null  int64
#  8   X_7                23856 non-null  int64
#  9   X_8                23856 non-null  int64
#  10  X_9                23856 non-null  int64
#  11  X_10               23856 non-null  int64
#  12  X_11               23856 non-null  int64
#  13  X_12               23674 non-null  float64
#  14  X_13               23856 non-null  int64
#  15  X_14               23856 non-null  int64
# ...

# %%
df = df.drop(columns = ['DATE'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23856 entries, 0 to 23855
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X_1                23856 non-null  int64
#  1   X_2                23856 non-null  int64
#  2   X_3                23856 non-null  int64
#  3   X_4                23856 non-null  int64
#  4   X_5                23856 non-null  int64
#  5   X_6                23856 non-null  int64
#  6   X_7                23856 non-null  int64
#  7   X_8                23856 non-null  int64
#  8   X_9                23856 non-null  int64
#  9   X_10               23856 non-null  int64
#  10  X_11               23856 non-null  int64
#  11  X_12               23674 non-null  float64
#  12  X_13               23856 non-null  int64
#  13  X_14               23856 non-null  int64
#  14  X_15               23856 non-null  int64
#  15  MALICIOUS_OFFENSE  23856 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# X_1                    0
# X_2                    0
# X_3                    0
# X_4                    0
# X_5                    0
# X_6                    0
# X_7                    0
# X_8                    0
# X_9                    0
# X_10                   0
# X_11                   0
# X_12                 182
# X_13                   0
# X_14                   0
# X_15                   0
# MALICIOUS_OFFENSE      0
# dtype: int64

# %%
sns.boxplot(df.X_12)
plt.show()
# Out:
# E:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
Q1 = df.X_12.quantile(0.25)
Q3 = df.X_12.quantile(0.75)
IQR = Q3 - Q1
df = df[(df.X_12 >= Q1 - 1.5*IQR) & (df.X_12 <= Q3 + 1.5*IQR)]

# %%
sns.boxplot(df.X_12)
plt.show()
# Out:
# E:\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15674 entries, 0 to 23855
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   X_1                15674 non-null  int64
#  1   X_2                15674 non-null  int64
#  2   X_3                15674 non-null  int64
#  3   X_4                15674 non-null  int64
#  4   X_5                15674 non-null  int64
#  5   X_6                15674 non-null  int64
#  6   X_7                15674 non-null  int64
#  7   X_8                15674 non-null  int64
#  8   X_9                15674 non-null  int64
#  9   X_10               15674 non-null  int64
#  10  X_11               15674 non-null  int64
#  11  X_12               15674 non-null  float64
#  12  X_13               15674 non-null  int64
#  13  X_14               15674 non-null  int64
#  14  X_15               15674 non-null  int64
#  15  MALICIOUS_OFFENSE  15674 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# X_1                  0
# X_2                  0
# X_3                  0
# X_4                  0
# X_5                  0
# X_6                  0
# X_7                  0
# X_8                  0
# X_9                  0
# X_10                 0
# X_11                 0
# X_12                 0
# X_13                 0
# X_14                 0
# X_15                 0
# MALICIOUS_OFFENSE    0
# dtype: int64

# %%
col = df.columns
col
# Out:
# Index(['X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 'X_7', 'X_8', 'X_9', 'X_10',
#        'X_11', 'X_12', 'X_13', 'X_14', 'X_15'],
#       dtype='object')

# %%
for i in col:
    a = df.value_counts(i)
    print(a)
# Out:
# X_1
# 0    12793
# 1     2178
# 7      466
# 5      142
# 3       68
# 4       18
# 2        6
# 6        3
# dtype: int64
# X_2
# 4     3038
# 36    1392
# 33    1155
# 24     831
# 21     786
# 37     670
# 45     618
# 49     610
# 3      563
# 16     467
# 9      430
# 22     380
# 39     347
# 25     344
# 40     312
# 5      294
# 47     285
# 44     271
# 26     259
# 6      247
# 19     246
# 30     192
# 17     167
# 35     140
# 18     135
# 42     132
# 7      128
# 50     110
# 38     104
# 46      94
# 23      88
# 11      81
# 29      73
# 15      68
# 2       67
# 41      67
# 43      53
# 8       52
# 28      49
# 34      45
# 51      44
# 14      43
# 32      39
# 20      37
# 31      35
# 48      24
# 1       17
# 0       17
# 27      12
# 52      11
# 13       4
# 10       1
# dtype: int64
# X_3
# 4     3038
# 34    1392
# 32    1155
# 24     831
# 23     786
# 37     670
# 45     618
# 49     610
# 2      563
# 15     467
# 10     430
# 22     380
# 39     347
# ...

# %%
y = df.pop('MALICIOUS_OFFENSE')

# %%
x = df

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.feature_selection import RFECV 

from sklearn.model_selection import StratifiedKFold

# %%
rfe = RFECV(RandomForestClassifier(), cv=StratifiedKFold(3))

# %%
rfe.fit(x,y)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=3, random_state=None, shuffle=False),
#       estimator=RandomForestClassifier())

# %%
rfe.n_features_
# Out:
# 3

# %%
x = rfe.transform(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=39)

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9993620414673047
