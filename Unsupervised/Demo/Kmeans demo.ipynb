# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("income.csv")

# %%
df
# Out:
#         Name  Age  Income($)
# 0        Rob   27      70000
# 1    Michael   29      90000
# 2      Mohan   29      61000
# 3     Ismail   28      60000
# 4       Kory   42     150000
# 5     Gautam   39     155000
# 6      David   41     160000
# 7     Andrea   38     162000
# 8       Brad   36     156000
# 9   Angelina   35     130000
# 10    Donald   37     137000
# 11       Tom   26      45000
# 12    Arnold   27      48000
# 13     Jared   28      51000
# 14     Stark   29      49500
# 15    Ranbir   32      53000
# 16    Dipika   40      65000
# 17  Priyanka   41      63000
# 18      Nick   43      64000
# 19      Alia   39      80000
# 20       Sid   41      82000
# 21     Abdul   39      58000

# %%
df.drop("Name",axis=1,inplace=True)

# %%
df.columns=['age','income']

# %%
df.head()
# Out:
#    age  income
# 0   27   70000
# 1   29   90000
# 2   29   61000
# 3   28   60000
# 4   42  150000

# %%
plt.scatter(df.age,df.income)

# %%
from sklearn.cluster import KMeans

# %%
k = KMeans(n_clusters=4)
ypred = k.fit_predict(df)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
k
# Out:
# KMeans(n_clusters=4)

# %%
ypred
# Out:
# array([1, 1, 3, 3, 0, 0, 0, 0, 0, 2, 2, 3, 3, 3, 3, 3, 3, 3, 3, 1, 1, 3])

# %%
df['cluster'] = ypred

# %%
df.head()
# Out:
#    age  income  cluster
# 0   27   70000        1
# 1   29   90000        1
# 2   29   61000        3
# 3   28   60000        3
# 4   42  150000        0

# %%
df0 = df[df.cluster==0]
df1 = df[df.cluster==1]
df2 = df[df.cluster==2]
df3 = df[df.cluster==3]

# %%
df1
# Out:
#     age  income  cluster
# 0    27   70000        1
# 1    29   90000        1
# 19   39   80000        1
# 20   41   82000        1

# %%
df2
# Out:
#     age  income  cluster
# 9    35  130000        2
# 10   37  137000        2

# %%
plt.scatter(df0.age,df0.income,color="green",label='0')
plt.scatter(df1.age,df1.income,color="blue",label='1')
plt.scatter(df2.age,df2.income,color="yellow",label='2')
plt.scatter(df3.age,df3.income,color="red",label='3')
plt.legend()

# %%
k = KMeans(n_clusters=3)
ypred = k.fit_predict(df)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df['cluster'] = ypred

# %%
df0 = df[df.cluster==0]
df1 = df[df.cluster==1]
df2 = df[df.cluster==2]
#df3 = df[df.cluster==3]

# %%
df
# Out:
#     age  income  cluster
# 0    27   70000        0
# 1    29   90000        0
# 2    29   61000        2
# 3    28   60000        2
# 4    42  150000        1
# 5    39  155000        1
# 6    41  160000        1
# 7    38  162000        1
# 8    36  156000        1
# 9    35  130000        1
# 10   37  137000        1
# 11   26   45000        2
# 12   27   48000        2
# 13   28   51000        2
# 14   29   49500        2
# 15   32   53000        2
# 16   40   65000        2
# 17   41   63000        2
# 18   43   64000        2
# 19   39   80000        0
# 20   41   82000        0
# 21   39   58000        2

# %%
plt.scatter(df0.age,df0.income,color="green",label='0')
plt.scatter(df1.age,df1.income,color="blue",label='1')
plt.scatter(df2.age,df2.income,color="yellow",label='2')
#plt.scatter(df3.age,df3.income,color="red",label='3')
plt.legend()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.drop("cluster",axis=1,inplace=True)

# %%
mm = MinMaxScaler()
df[['age','income']]  =  mm.fit_transform(df)

# %%
df.head()
# Out:
#         age    income
# 0  0.058824  0.213675
# 1  0.176471  0.384615
# 2  0.176471  0.136752
# 3  0.117647  0.128205
# 4  0.941176  0.897436

# %%
plt.scatter(df.age,df.income)

# %%
k = KMeans(n_clusters=3)
ypred = k.fit_predict(df)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
df['cluster'] = ypred

# %%
df0 = df[df.cluster==0]
df1 = df[df.cluster==1]
df2 = df[df.cluster==2]
#df3 = df[df.cluster==3]

# %%
plt.scatter(df0.age,df0.income,color="green",label='0')
plt.scatter(df1.age,df1.income,color="blue",label='1')
plt.scatter(df2.age,df2.income,color="yellow",label='2')
#plt.scatter(df3.age,df3.income,color="red",label='3')
plt.legend()

# %%
k.inertia_# k=3 #ssd
# Out:
# 0.4750783498553096

# %%
ssd = []
for i in range(1,11):
    k = KMeans(n_clusters=i)
    k.fit(df)
    ssd.append(k.inertia_)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
ssd
# Out:
# [18.38855696653363,
#  5.945614491472593,
#  0.4750783498553096,
#  0.34910470944195654,
#  0.2621792762345213,
#  0.21878010893330446,
#  0.17299621932455467,
#  0.13265419827245162,
#  0.11123550695239098,
#  0.08305638380794388]

# %%
plt.plot(range(1,11),ssd)

# %%
df
# Out:
#          age    income  cluster
# 0   0.058824  0.213675        1
# 1   0.176471  0.384615        1
# 2   0.176471  0.136752        1
# 3   0.117647  0.128205        1
# 4   0.941176  0.897436        2
# 5   0.764706  0.940171        2
# 6   0.882353  0.982906        2
# 7   0.705882  1.000000        2
# 8   0.588235  0.948718        2
# 9   0.529412  0.726496        2
# 10  0.647059  0.786325        2
# 11  0.000000  0.000000        1
# 12  0.058824  0.025641        1
# 13  0.117647  0.051282        1
# 14  0.176471  0.038462        1
# 15  0.352941  0.068376        1
# 16  0.823529  0.170940        0
# 17  0.882353  0.153846        0
# 18  1.000000  0.162393        0
# 19  0.764706  0.299145        0
# 20  0.882353  0.316239        0
# 21  0.764706  0.111111        0

# %%
from sklearn.metrics import silhouette_score

# %%
k = KMeans(n_clusters=3)
ypred = k.fit_predict(df)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
silhouette_score(df,ypred)
# Out:
# 0.8440618526317891

# %%
ssd = []
ss = []
for i in range(2,11):
    k = KMeans(n_clusters=i)
    k.fit(df)
    ypred = k.predict(df)
    ss.append(silhouette_score(df,ypred))
    ssd.append(k.inertia_)
# Out:
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\AKASH\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1334: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
plt.plot(range(2,11),ssd)

# %%
plt.plot(range(2,11),ss)
